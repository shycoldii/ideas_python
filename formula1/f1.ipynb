# %%
import requests
from bs4 import BeautifulSoup

def get_site(url):
    return requests.get(url)

def parse_teams(table):
    """Возвращает словарь Команда: Очки"""
    names = []
    teams = table.find("tbody").find_all("tr")
    result = {}
    temp = []
    for i in range(len(teams)):
            temp.append(teams[i].find_all("td"))
    for i in temp:
        names.append(i[-1].text)
    for i in teams:
        names.append(i.find("a").text)
    for i in range(len(names)//2):
        result[names[i+len(names)//2]]= names[i]
    r=1
    for i in result.items():
        print(str(r)+ ". "+i[0]+" ("+i[1]+")")
        r+=1
    return result
def parse_dates(api,key=1):
    """Получает с сайта даты и названия турнира и отдает в управление в обертку-функцию"""
    result=BeautifulSoup(api.text,'html.parser')
    dates = result.find_all("div",class_="stat mB6")
    temp,titles = [],[]
    ret ={}
    new1,new2,res1,res2 = [],[],[],[]
    titles = result.find_all("h3")
    for i in range(len(titles)):
        titles[i] = titles[i].text
    for i in range(len(dates)):
        temp.append(dates[i].find("tbody").find_all("tr"))
    
    for i in range(len(dates)):
        new1.append(dates[i].find_all("td",class_="name-td alLeft bordR"))
        new2.append(dates[i].find_all("td",class_="name-td alLeft"))

    for i in range(len(new1)):
        res1.append(new1[i][1].find("a").text)
        res1.append(new1[i][2].find("a").text)
        try:
            res2.append(new2[i][1].find("a").text)
        except:
            res2.append("-")
        try:
            res2.append(new2[i][2].find("a").text)
        except:
            res2.append("-")
    for i in range(len(res1)):
        ret[res1[i]] = res2[i]
    nice_wrapper_dates(titles,res1,res2,key)
    

def nice_wrapper_dates(titles,res1,res2,key=1):
    """Красивое оформление кода для дат"""
    kk=0
    if key == 1:
        for i in range(len(titles)):
            print(titles[i])
            print(res1[kk]+" "+res2[kk])
            print(res1[kk+1]+" "+res2[kk+1])
            print('\n')
            kk+=2
    for i in range(len(res2)):
        if res2[i]=="-":
            print("Ближайший турнир - это"+f' "{titles[i//2]}"'+" "+res1[i]+res1[i+1])
            break
def main():     
    print("----------------------------------")
    print("Для общих сведений дат введите 1")
    print("Для таблицы команд введите 2")
    print("Для таблицы личных зачетов введите 3")
    print("----------------------------------")
    scanner = input()
    if scanner == "1":
        url1 ='https://www.sports.ru/f1-championship/calendar/'
        sc = input("Показать прошедшие матчи? n, если нет")
        api1 =get_site(url1)
        if api1.status_code == 200:
             if sc == "n":
                parse_dates(api1,0)
             else:
                parse_dates(api1,1)



    url1 = "https://www.sports.ru/f1-championship/table/"
    api1 =get_site(url1)
    result=BeautifulSoup(api1.text,'html.parser')
    table = result.find_all("table",class_="stat-table table")
    if scanner == "2":
        teams = parse_teams(table[1])
    if scanner =="3":
        teams = parse_teams(table[0])
if __name__ =="__main__":
    main()
# Out:
# ----------------------------------
# Для общих сведений дат введите 1
# Для таблицы команд введите 2
# Для таблицы личных зачетов введите 3
# ----------------------------------
# 1
# Показать прошедшие матчи? n, если нетf
# Гран-при Австрии
#
# 04.07.2020|16:00 Валттери Боттас
#
# 05.07.2020|16:00 Валттери Боттас
#
#
# Гран-при Штирии
#
# 11.07.2020|16:00 Льюис Хэмилтон
#
# 12.07.2020|16:00 Льюис Хэмилтон
#
#
# Гран-при Венгрии
#
# 18.07.2020|16:00 Льюис Хэмилтон
#
# 19.07.2020|16:10 Льюис Хэмилтон
#
#
# Гран-при Великобритании
#
# 01.08.2020|17:00 Льюис Хэмилтон
#
# 02.08.2020|17:10 Льюис Хэмилтон
#
#
# Гран-при 70-летия Формулы-1
#
# 08.08.2020|17:00 Валттери Боттас
#
# 09.08.2020|17:10 Макс Ферстаппен
#
#
# Гран-при Испании
#
# 15.08.2020|16:00 Льюис Хэмилтон
#
# 16.08.2020|16:10 Льюис Хэмилтон
#
#
# Гран-при Бельгии
#
# 29.08.2020|16:00 Льюис Хэмилтон
#
# 30.08.2020|16:10 Льюис Хэмилтон
#
#
# Гран-при Италии
#
# 05.09.2020|16:00 Льюис Хэмилтон
#
# 06.09.2020|16:10 Пьер Гасли
#
#
# Гран-при Тосканы
#
# 12.09.2020|16:00 Льюис Хэмилтон
#
# 13.09.2020|16:10 Льюис Хэмилтон
#
#
# Гран-при России
#
# 26.09.2020|13:00 Льюис Хэмилтон
#
# 27.09.2020|13:10 Валттери Боттас
#
#
# Гран-при Айфеля
#
# 10.10.2020|16:00 Валттери Боттас
#
# 11.10.2020|15:10 Льюис Хэмилтон
#
#
# Гран-при Португалии
#
# 24.10.2020|16:00 -
#
# 25.10.2020|16:10 -
#
#
# Гран-при Эмилии-Романьи
#
# 31.10.2020|16:00 -
#
# 01.11.2020|15:10 -
#
#
# Гран-при Турции
#
# 14.11.2020|15:00 -
#
# 15.11.2020|13:10 -
#
#
# Гран-при Бахрейна
#
# 28.11.2020|18:00 -
#
# 29.11.2020|18:10 -
#
#
# Гран-при Сахира
#
# 05.12.2020|21:00 -
#
# 06.12.2020|20:10 -
#
#
# Гран-при Абу-Даби
#
# 12.12.2020|16:00 -
#
# 13.12.2020|16:10 -
#
#
# Ближайший турнир - это "Гран-при Португалии"
# 24.10.2020|16:00
# 25.10.2020|16:10
